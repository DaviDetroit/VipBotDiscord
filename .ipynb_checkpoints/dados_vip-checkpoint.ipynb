# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector

# Configuração da conexão - substitua pela sua senha e banco
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='sua_senha_aqui',
    database='SistemaVips'
)

# Consulta SQL para pegar os dados
query = "SELECT id, nome_discord, data_inicio FROM vips"

# Lê os dados direto para o pandas
df = pd.read_sql(query, conn)

# Converte para datetime
df['data_inicio'] = pd.to_datetime(df['data_inicio'])

# Agrupa por mês/ano
df['mes_ano'] = df['data_inicio'].dt.to_period('M')

# Conta quantos cadastros por mês
contagem = df.groupby('mes_ano').size()

# Plotando o gráfico
plt.figure(figsize=(10,5))
contagem.plot(kind='bar', color='skyblue')
plt.title('Cadastros VIP por Mês')
plt.xlabel('Mês/Ano')
plt.ylabel('Quantidade de Cadastros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File D:\vscoisas\ProjetoVipBot\.venv\Lib\site-packages\mysql\connector\connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 6
#       3 import mysql.connector
#       5 # Configuração da conexão - substitua pela sua senha e banco
# ----> 6 conn = mysql.connector.connect(
#       7     host='localhost',
#       8     user='root',
#       9     password='sua_senha_aqui',
#      10     database='SistemaVips'
#      11 )
#      13 # Consulta SQL para pegar os dados
#      14 query = "SELECT id, nome_discord, data_inicio FROM vips"
#
# File D:\vscoisas\ProjetoVipBot\.venv\Lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File D:\vscoisas\ProjetoVipBot\.venv\Lib\site-packages\mysql\connector\connection_cext.py:142, in CMySQLConnection.__init__(self, **kwargs)
#     140 if kwargs:
#     141     try:
# --> 142         self.connect(**kwargs)
#     143     except Exception:
#     144         self.close()
#
# File D:\vscoisas\ProjetoVipBot\.venv\Lib\site-packages\mysql\connector\abstracts.py:1605, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1602     self.config(**kwargs)
#    1604 self.disconnect()
# -> 1605 self._open_connection()
#    1607 charset, collation = (
#    1608     kwargs.pop("charset", None),
#    1609     kwargs.pop("collation", None),
#    1610 )
#    1611 if charset or collation:
#
# File D:\vscoisas\ProjetoVipBot\.venv\Lib\site-packages\mysql\connector\connection_cext.py:360, in CMySQLConnection._open_connection(self)
#     358 except MySQLInterfaceError as err:
#     359     if hasattr(err, "errno"):
# --> 360         raise get_mysql_exception(
#     361             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     362         ) from err
#     363     raise InterfaceError(str(err)) from err
#     365 self._do_handshake()
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector

# Conexão ao banco
conn = mysql.connector.connect(
    host='localhost',
    user='fernandez',
    password='root007',
    database='SistemaVips'
)

# Consulta
query = "SELECT id, nome_discord, data_inicio FROM vips"
df = pd.read_sql(query, conn)
df['data_inicio'] = pd.to_datetime(df['data_inicio'])

# Agrupar por mês/ano
df['mes_ano'] = df['data_inicio'].dt.to_period('M')
contagem = df.groupby('mes_ano').size()

# Plotar gráfico com melhorias visuais
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(9,4))  # mais compacto

bars = ax.bar(contagem.index.astype(str), contagem.values,
              color='#4C72B0', edgecolor='black', linewidth=0.8)

ax.set_title('Cadastros VIP por Mês', fontsize=14, fontweight='bold')
ax.set_xlabel('Mês/Ano', fontsize=11)
ax.set_ylabel('Quantidade', fontsize=11)

ax.set_xticklabels(contagem.index.astype(str), rotation=45, ha='right', fontsize=9)

# Mostrar valor no topo das barras
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # distância do texto para a barra
                textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9,
                color='black')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_19592\486910219.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# C:\Users\PC\AppData\Local\Temp\ipykernel_19592\486910219.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(contagem.index.astype(str), rotation=45, ha='right', fontsize=9)
